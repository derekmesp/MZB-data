# %%
import scanpy as sc 
import numpy as np
import pandas as pd  
from pathlib import Path

# %%
file_path = "HES4.h5ad"
adata = sc.read_h5ad(file_path)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 91720 × 19288
#     obs: 'age', 'batch', 'chemistry', 'cmv', 'donor', 'ebv', 'library', 'n_genes', 'n_proteins', 'sample', 'sex', 'site', 'tissue', 'total_counts', 'age_donor', 'age_groups', 'annotation', 'annotation_analysis', 'annotation_gross', 'tissue_groups', 'blo', 'bma', 'spl', 'ln', 'resp', 'gut', 'SampleID', 'donor_tissue', 'donor_tissue_groups', 'donor_tissue_groups_annotation', 'donor_annotation', 'tissue_groups_annotation', 'annotation_analysis_v2', 'tissue_groups_annotation_analysis_v2', 'tissue_groups_age_groups'
#     var: 'feature_types', 'Accession', 'hb', 'hsp', 'is_highly_variable_gene_batch_key_donor_id', 'is_highly_variable_gene_batch_key_donor_id+tissue', 'mt', 'ribo'
#     uns: 'age_groups_colors', 'annotation_analysis_colors', 'annotation_colors', 'annotation_gross_colors', 'chemistry_colors', 'cmv_colors', 'donor_colors', 'ebv_colors', 'ff_save_history', 'log1p', 'sex_colors', 'site_colors', 'tissue_colors'
# ...

# %%
sc.pl.embedding(adata, basis='umap_mrvi_compartment_06OCT2023', color='annotation_analysis_v2')

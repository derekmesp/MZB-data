# %%
import numpy as np
import pandas as pd  
import dandelion as ddl

# %%
vdj = ddl.read_h5ddl("Bcells_dandelion.h5ddl")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 vdj = ddl.read_h5ddl("Bcells_dandelion.h5ddl")
#
# File /usr/local/lib/python3.11/site-packages/dandelion/utilities/_io.py:173, in read_h5ddl(filename)
#     154 def read_h5ddl(filename: Path | str = "dandelion_data.h5ddl") -> Dandelion:
#     155     """
#     156     Read in and returns a `Dandelion` class from .h5ddl format.
#     157
#    (...)
#     171         if `data` not found in `.h5ddl` file.
#     172     """
# --> 173     data = load_data(_read_h5_group(filename, group="data"))
#     174     metadata = _read_h5_group(filename, group="metadata")
#     175     try:
#
# File /usr/local/lib/python3.11/site-packages/dandelion/utilities/_io.py:1269, in _read_h5_group(filename, group)
#    1248 """
#    1249 Read a specific group from an H5 file.
#    1250
#    (...)
# ...

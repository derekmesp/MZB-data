# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel(
    "Liquid Nitrogen Storage.xlsx",
    keep_default_na=False,
    engine="openpyxl"
)
# Out:
# Index(['Donor', 'Prior Claim', 'Age(y): 45(+/-20)', 'Sex: M-378 F-234', 'LN',
#        'Rack', 'Row', '# of Samples: (N=19186)', 'Blood\nPlasma', 'Unnamed: 9',
#        'BAL\n Supernatant', 'Unnamed: 11', 'Bone\nMarrow\nPlasma',
#        'Unnamed: 13', 'Appendix', 'Unnamed: 15', 'Bronchoalveolar\n Lavage',
#        'Unnamed: 17', 'Blood', 'Unnamed: 19', 'Bone\n Marrow', 'Unnamed: 21',
#        'Colon\n Epithelial\n Layer - Ascending', 'Unnamed: 23',
#        'Colon\n Lamina\n Propria - Ascending', 'Unnamed: 25',
#        'Colon\n Epithelial\n Layer - Descending', 'Unnamed: 27',
#        'Colon\n Lamina\n Propria - Descending', 'Unnamed: 29',
#        'Colonic\nLymph\nNodes', 'Unnamed: 31', 'Duodenum\n Epithelial\n Layer',
#        'Unnamed: 33', 'Duodenum\n Lamina\n Propria', 'Unnamed: 35',
#        'Hepatic\n Lymph\n Nodes', 'Unnamed: 37', 'Illeum\n Epithelial\n Layer',
#        'Unnamed: 39', 'Illeum\n Lamina\n Propria', 'Unnamed: 41',
#        'Inguinal\n Lymph\n Nodes', 'Unnamed: 43',
#        'Jejunum\n Epithelial\n Layer', 'Unnamed: 45',
#        'Jejunum\n Lamina\n Propria', 'Unnamed: 47', 'Liver', 'Unnamed: 49',
#        'Lung- Apex', 'Unnamed: 51', 'Lung- Base', 'Unnamed: 53',
#        'Lung\n Lymph\n Nodes', 'Unnamed: 55', 'Mesenteric\n Lymph\n Nodes',
#        'Unnamed: 57', 'Mesenteric\n Adipose\n Tissue', 'Unnamed: 59',
#        'Pancreas', 'Unnamed: 61', 'Pancreatic\n Lymph\n Nodes', 'Unnamed: 63',
#        'Peyer's\n Patches', 'Unnamed: 65', 'Salivary Gland', 'Unnamed: 67',
#        'Spleen', 'Unnamed: 69', 'Tonsil', 'Unnamed: 71', 'Thymus',
#        'Unnamed: 73', 'Hilar\nLymph\nNodes', 'Unnamed: 75',
#        'Tracheal\nLymph\nNodes', 'Unnamed: 77', 'Other'],
#       dtype='object')

# %%
cols = [
    "Blood",
    "Bone\n Marrow",
    "Spleen",
    "Inguinal\n Lymph\n Nodes",
    "Lung\n Lymph\n Nodes",
    "Mesenteric\n Lymph\n Nodes",
    "Colon\n Lamina\n Propria - Ascending",
    "Colon\n Lamina\n Propria - Descending"
]

# %%
df[cols] = (
    df[cols]
    .replace(r"N=\s*", "", regex=True)
    .apply(pd.to_numeric, errors="coerce")
)

filtered = df[df[cols].gt(0).all(axis=1)]

# %%
filtered = df[(df[cols] > 0).sum(axis=1) == 5]
print(filtered.Donor.unique())
# Out:
# ['D0085' 'D0110' 'D0120' 'D0129' 'D0148' 'D0152' 'D0163' 'D0173' 'D0203'
#  'D0204' 'D0209' 'D0240' 'D0273' 'D0326' 'D0333' 'D0353' 'D0363' 'D0459'
#  'D0468' 'D0487' 'D0490' 'D0508' 'D0511' 'D0515' 'D0524' 'D0538' 'D0545'
#  'D0559' 'D0572' 'D0578' 'D0600' 'D0605' 'D0610' 'D0612' 'D0616' 'D0623'
#  'D0631' 'D0633' 'D0638' 'D0651' 'D0656' 'D0657' 'D0667' 'D0669' 'D0670'
#  'D0676' 'D0679' 'D0681' 'D0685' 'D0688' 'D0692' 'D0694' 'D0695' 'D0696'
#  'D0697' 'D0701' 'D0707' 'D0713' 'D0714' 'D0715' 'D0717' 'D0723']
